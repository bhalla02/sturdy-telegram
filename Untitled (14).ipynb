# %% [markdown]
# Q1
#
# The Probability Density Function (PDF) is a function used in probability theory and statistics to describe the probability distribution of a continuous random variable. It assigns probabilities to intervals rather than to specific values. Mathematically, for a continuous random variable
# �
# X, the PDF is denoted as
# �
# (
# �
# )
# f(x), where
# �
# (
# �
# )
# f(x) represents the likelihood of the random variable taking on a particular value
# �
# x. The PDF satisfies the following properties:

# %% [markdown]
# Q2
# There are several types of probability distributions, each serving different purposes and applicable to different scenarios. Some common types of probability distributions include:
#
# Discrete Probability Distributions:
#
# Bernoulli Distribution: Models a binary outcome (success/failure) with a single trial.
# Binomial Distribution: Models the number of successes in a fixed number of independent Bernoulli trials.
# Poisson Distribution: Models the number of events occurring in a fixed interval of time or space when events occur independently at a constant average rate.
# Continuous Probability Distributions:
#
# Normal Distribution: Often referred to as the bell curve, it's characterized by its symmetric, bell-shaped curve.
# Uniform Distribution: All outcomes within a given range are equally likely.
# Exponential Distribution: Models the time until an event occurs, such as the waiting time between two successive events in a Poisson process.
# Student's t-Distribution: Used for inference concerning the mean of normally distributed populations when the sample size is small and the population standard deviation is unknown.
# Chi-Squared Distribution: Used in hypothesis testing and confidence interval estimation for the variance of a normally distributed population.

# %%
'''Q3'''

import math

def normal_pdf(x,mean,std_dev):
    coefficient = 1/math.sqrt( 2 * math.pi * std_dev**2)
    exponent = -((x - mean)**2) / (2 * std_dev**2)
    pdf_value = coefficient*math.exp(exponent)
    return pdf_value
    
x = 1
std_dev = 1
mean = 0

pdf_at_x = normal_pdf(x, mean, std_dev)
print("PDF at x =", x, ":", pdf_at_x)
# Out:
# PDF at x = 1 : 0.24197072451914337

# %% [markdown]
# The Binomial distribution has several key properties:
#
# Discreteness: The Binomial distribution is used to model the number of successes (usually denoted as
# �
# k) in a fixed number of independent Bernoulli trials (usually denoted as
# �
# n), where each trial has only two possible outcomes (success or failure).
#
# Fixed Number of Trials: The number of trials,
# �
# n, is fixed and known in advance.
#
# Independence: Each trial is independent of the others, meaning that the outcome of one trial does not affect the outcomes of the other trials.
#
# Constant Probability of Success: The probability of success, denoted as
# �
# p, remains constant from trial to trial.
#
# Two Possible Outcomes: Each trial has two possible outcomes: success (with probability
# �
# p) and failure (with probability
# 1
# −
# �
# 1−p).
#
# Examples of events where the Binomial distribution can be applied include:
#
# Coin Flipping: Suppose you flip a fair coin 10 times and want to calculate the probability of getting exactly 7 heads. Each flip of the coin represents a Bernoulli trial with a probability of success (getting heads) of 0.5. The number of successes (heads) in 10 trials follows a Binomial distribution with parameters
# �
# =
# 10
# n=10 and
# �
# =
# 0.5
# p=0.5.
#
# Product Defects: Imagine a manufacturing process that produces light bulbs, and each bulb has a 5% chance of being defective. If you randomly select 20 bulbs from the production line, you can use the Binomial distribution to calculate the probability of finding a specific number of defective bulbs among the 20 sampled bulbs. Each bulb being defective or not can be considered a Bernoulli trial, and the number of defective bulbs in 20 trials follows a Binomial distribution with parameters
# �
# =
# 20
# n=20 and
# �
# =
# 0.05
# p=0.05.

# %%
#Q5

import numpy as np
import matplotlib.pyplot as plt

sample_size = 1000
probability_success = 0.4

random_sample = np.random.binomial(n=1, p=probability_success, size=sample_size)


plt.hist(random_sample , bins=[-0.5,0.5,1.5] , edgecolor = 'black' , alpha = 0.7)
plt.xticks([0, 1], ['Failure', 'Success'])
plt.xlabel('Outcome')
plt.ylabel('Frequency')
plt.title('Histogram of Binomial Distribution Sample')
plt.grid(True)
plt.show()

# %%
#Q6

import math

def poisson_cdf(k, mean):
   
    cdf = 0
    for i in range(k + 1):
        cdf += math.exp(-mean) * (mean**i) / math.factorial(i)
    return cdf

# Example usage:
mean = 3
point = 5
cdf_at_point = poisson_cdf(point, mean)
print("CDF at point", point, ":", cdf_at_point)
# Out:
# CDF at point 5 : 0.9160820579686966

# %% [markdown]
# Q7
#
# The Binomial distribution and Poisson distribution are both probability distributions commonly used in statistics, but they are applicable in different scenarios and have distinct characteristics. Here are the key differences between the Binomial distribution and Poisson distribution:
#
# Nature of Events:
#
# Binomial Distribution: The Binomial distribution is used to model the number of successes in a fixed number of independent Bernoulli trials, where each trial has only two possible outcomes (success or failure).
# Poisson Distribution: The Poisson distribution is used to model the number of events occurring in a fixed interval of time or space, assuming that the events occur independently at a constant average rate.
# Number of Trials:
#
# Binomial Distribution: The number of trials in a Binomial distribution is fixed and known in advance.
# Poisson Distribution: There is no fixed number of trials in a Poisson distribution; it represents events occurring continuously over a fixed interval.
# Probability of Success:
#
# Binomial Distribution: In the Binomial distribution, the probability of success (denoted as
# �
# p) remains constant from trial to trial.
# Poisson Distribution: In the Poisson distribution, the average rate of event occurrence (denoted as
# �
# λ) is constant across the interval.
# Assumptions:
#
# Binomial Distribution: The Binomial distribution assumes a fixed number of trials, each with a constant probability of success, and independence between trials.
# Poisson Distribution: The Poisson distribution assumes a large number of trials or a continuous process with a low probability of success for each trial.
# Limiting Behavior:
#
# Binomial Distribution: As the number of trials (
# �
# n) increases and the probability of success (
# �
# p) approaches zero while the product
# �
# �
# np remains constant, the Binomial distribution converges to the Poisson distribution.
# Poisson Distribution: The Poisson distribution is often used as an approximation for the Binomial distribution when the number of trials is large and the probability of success is small, resulting in a small average rate of event occurrence.
# In summary, while both distributions deal with counting events, the Binomial distribution is suited for a fixed number of independent trials with a constant probability of success, whereas the Poisson distribution is suitable for modeling the occurrence of rare events over a continuous interval with a constant average rate.

# %%
#Q8
import numpy as np

# Parameters
sample_size = 1000
mean = 5

# Generate random sample from Poisson distribution
random_sample = np.random.poisson(mean, size=sample_size)

# Calculate sample mean and variance
sample_mean = np.mean(random_sample)
sample_variance = np.var(random_sample)

print("Sample Mean:", sample_mean)
print("Sample Variance:", sample_variance)
# Out:
# Sample Mean: 5.001
# Sample Variance: 5.0309989999999996

# %% [markdown]
# Q9
# In both the Binomial distribution and Poisson distribution, the mean and variance are related, but the specific relationship differs slightly between the two distributions.
#
# Binomial Distribution:
#
# Mean (
# �
# μ) =
# �
# ×
# �
# n×p
# Variance (
# �
# 2
# σ
# 2
#  ) =
# �
# ×
# �
# ×
# (
# 1
# −
# �
# )
# n×p×(1−p)
# In the Binomial distribution:
#
# The mean is directly proportional to the number of trials (
# �
# n) and the probability of success (
# �
# p).
# The variance is also directly proportional to the number of trials (
# �
# n), the probability of success (
# �
# p), and the probability of failure (
# 1
# −
# �
# 1−p).
# Poisson Distribution:
#
# Mean (
# �
# λ) = Variance (
# �
# 2
# σ
# 2
#  ) =
# �
# λ
# In the Poisson distribution:
#
# Both the mean and variance are equal and are represented by the parameter
# �
# λ, which is the average rate of event occurrence.
# The variance is always equal to the square of the mean (
# �
# 2
# =
# �
# ×
# �
# =
# �
# 2
# σ
# 2
#  =λ×λ=λ
# 2
#  ).
# In summary:
#
# In the Binomial distribution, the variance depends on both the number of trials and the probability of success and failure, while in the Poisson distribution, the variance is solely determined by the average rate of event occurrence.
# However, in both distributions, when the mean is large, the variance also tends to be large, and vice versa. This relationship between the mean and variance helps characterize the spread of the distribution and is important in understanding the
